# %% [markdown]
# <a href="https://colab.research.google.com/github/SecretDiscorder/PyShic/blob/main/kalkulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

def penjumlahan():
  a= (float(input("Masukan nilai pertama: ")));
  b= (float(input("Masukan nilai kedua: ")));
  c= a+b;
  print(c);

def pengurangan():
  a= (float(input("Masukan nilai pertama: ")));
  b= (float(input("Masukan nilai kedua: ")));
  c= a-b;
  print(c);
def spldv():
  a= (float(input("Masukan nilai x1: ")));
  b= (float(input("Masukan nilai y1: ")));
  hasil1= (float(input("hasil x1+y1= ")));
  c= (float(input("Masukan nilai x2: ")));
  d= (float(input("Masukan nilai y2: ")));
  hasil2= (float(input("hasil x2+y2= ")));
  determinan= (a*d)-(b*c);
  determinan_x= (d*hasil1)-(b*hasil2);
  determinan_y= (a*hasil2)-(c*hasil1);
  x= determinan_x/determinan;
  y= determinan_y/determinan;
  print("determinan: ", determinan);

  print("determinan_x: ", determinan_x);

  print("determinan_y: ", determinan_y);


  print("x: ", x);
  print("y: ", y);


def pembagian():
  a= (float(input("Masukan nilai pertama: ")));
  b= (float(input("Masukan nilai kedua: ")));
  c= a/b;
  print(c);

def perkalian():
  a= (float(input("Masukan nilai pertama: ")));
  b= (float(input("Masukan nilai kedua: ")));
  c= a*b;
  print(c);

def pangkat():
  a= (float(input("masukan bilangan: ")));
  b= (float(input("masukan pangkat: ")));
  c= math.pow(a, b);
  print(c);

def kuadrat():
  a= (float(input("masukan bilangan: ")));

  c= math.sqrt(a);
  print(c);

def logaritma():
  a= (float(input("masukan bilangan a (untuk a log b): ")));
  b= (float(input("masukan Bilangan b (untuk a log b): ")));

  c= math.log(b, a);

  print(c);
def sincostan():
  a= (int(input("masukan bilangan sin(derajat):  ")));
  d1= math.radians(a);
  c1= math.sin(d1);

  d2= math.radians(a);
  c2= math.cos(d2);

  d3= math.radians(a);
  c3= math.tan(d3);

  print("jadi sin= ",(c1));
  print("jadi cos= ",(c2));
  print("jadi tan= ",(c3));
def degree():
  b= (float(input("masukan bilangan(hasil berupa derajat) : ")));
  c= math.asin(b); #radian
  d= math.degrees(c); #derajat
  c2= math.acos(b); #radian
  d2= math.degrees(c2); #derajat
  print("derajat sin",(d))
  print("derajat cos",(d2))
  return 0;
def main():
  print("program kalkulator");
  print("1. penjumlahan");
  print("2. pengurangan");
  print("3. perkalian");
  print("4. pembagian");
  print("5. pangkat");
  print("6. kuadrat");
  print("7. logaritma");
  print("8. sincostan");
  print("9. Sin to degree");
  print("10. SPLDV");
  pilihan = (int(input("masukan pilihan anda: ")))
  if pilihan == 1:
    penjumlahan();
  elif pilihan == 2:
    pengurangan();
  elif pilihan == 3:
    perkalian();
  elif pilihan == 4:
    pembagian();
  elif pilihan == 5:
    pangkat();
  elif pilihan == 6:
    kuadrat();
  elif pilihan == 7:
    logaritma();
  elif pilihan == 8:
    sincostan();
  elif pilihan == 9:
    degree();
  elif pilihan == 10:
    spldv();1
  else :
    while True:
      main();
  return pilihan;

if __name__ == "__main__":
    main()
# Out:
# program kalkulator
# 1. penjumlahan
# 2. pengurangan
# 3. perkalian
# 4. pembagian
# 5. pangkat
# 6. kuadrat
# 7. logaritma
# 8. sincostan
# 9. Sin to degree
# 10. SPLDV
# masukan pilihan anda: 10
# Masukan nilai x1: 2
# Masukan nilai y1: 1
# hasil x1+y1= 3
# Masukan nilai x2: 3
# Masukan nilai y2: 5
# hasil x2+y2= 1
# determinan:  7.0
# determinan_x:  14.0
# determinan_y:  -7.0
# x:  2.0
# y:  -1.0
